# %% [markdown]
# <a href="https://colab.research.google.com/github/sreenathsnv/AI-ML/blob/DL/DeepLearning_pt3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Deep Learning #3

# %% [markdown]
# ## Matrix Operation

# %%
import numpy as np

# %%
revenue = np.array([[180,200,220],[24,36,40],[12,18,20]])
expenses = np.array([[80,90,100],[10,16,20],[8,10,10]])

# %%
profit  = revenue - expenses
profit
# Out:
# array([[100, 110, 120],
#        [ 14,  20,  20],
#        [  4,   8,  10]])

# %%
price_per_unit = np.array([1000,400,1200]) # refer broadcast
units = np.array([[30,40,50],[5,10,15],[2,5,7]])

# %%
price_per_unit * units
# Out:
# array([[30000, 16000, 60000],
#        [ 5000,  4000, 18000],
#        [ 2000,  2000,  8400]])

# %%
np.dot(price_per_unit,units) # matrix multiplication
# Out:
# array([34400, 50000, 64400])
